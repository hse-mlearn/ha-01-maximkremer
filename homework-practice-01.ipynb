# %% [markdown]
# # Машинное обучение, ФЭН ВШЭ
#
# ## Практическое задание 1
#
# ### Общая информация
# Дата выдачи: 19.09.2019
#
# Мягкий дедлайн: 23:59MSK 27.09.2019 (за каждый день просрочки снимается 1 балл)
#
# Жесткий дедлайн: 23:59MSK 04.10.2019

# %% [markdown]
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки pandas и визуализации с помощью matplotlib. В каждом разделе вам предлагается выполнить несколько заданий. Баллы даются за выполнение отдельных пунктов. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотекам pandas и matplotlib.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов.
#
# Сдавать задание после указанного срока сдачи нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# ### Формат сдачи
# Будет объявлен позже.

# %% [markdown]
# ## 0. Введение

# %% [markdown]
# Сейчас мы находимся в jupyter-ноутбуке (или ipython-ноутбуке). Это удобная среда для написания кода, проведения экспериментов, изучения данных, построения визуализаций и других нужд, не связанных с написаем production-кода.
#
# Ноутбук состоит из ячеек, каждая из которых может быть либо ячейкой с кодом, либо ячейкой с текстом размеченным и неразмеченным. Текст поддерживает markdown-разметку и формулы в Latex.
#
# Для работы с содержимым ячейки используется *режим редактирования* (*Edit mode*, включается нажатием клавиши **Enter** после выбора ячейки), а для навигации между ячейками искользуется *командный режим* (*Command mode*, включается нажатием клавиши **Esc**). Тип ячейки можно задать в командном режиме либо с помощью горячих клавиш (**y** to code, **m** to markdown, **r** to edit raw text), либо в меню *Cell -> Cell type*.
#
# После заполнения ячейки нужно нажать *Shift + Enter*, эта команда обработает содержимое ячейки: проинтерпретирует код или сверстает размеченный текст.

# %%
# ячейка с кодом, при выполнении которой появится output
2 + 2
# Out:
# 4

# %% [markdown]
# А это ___ячейка с текстом___.

# %% [raw]
# Ячейка с неразмеченыным текстом.

# %% [markdown]
# Попробуйте создать свои ячейки, написать какой-нибудь код и текст какой-нибудь формулой.

# %%
2 * 21
# Out:
# 42

# %% [markdown]
# [Здесь](https://athena.brynmawr.edu/jupyter/hub/dblank/public/Jupyter%20Notebook%20Users%20Manual.ipynb) находится <s>не</s>большая заметка о используемом языке разметки Markdown. Он позволяет:
#
# 0. Составлять упорядоченные списки
# 1. #Делать
# ##заголовки
# ###разного уровня
# 3. Выделять *текст* <s>при</s> **необходимости**
# 4. Добавлять [ссылки](http://imgs.xkcd.com/comics/the_universal_label.png)
#
#
# * Составлять неупорядоченные списки
#
# Делать вставки с помощью LaTex:
#
# $
# \left\{
# \begin{array}{ll}
# x = 16 \sin^3 (t) \\
# y = 13 \cos (t) - 5 \cos (2t) - 2 \cos (3t) - \cos (4t) \\
# t \in [0, 2 \pi]
# \end{array}
# \right.$

# %% [markdown]
# А ещё можно вставлять картинки:
# <img src="https://st2.depositphotos.com/1177973/9266/i/950/depositphotos_92668716-stock-photo-red-cat-with-computer-keyboard.jpg" style="width: 400px">

# %% [markdown]
# ## 1. Табличные данные и Pandas

# %% [markdown]
# Pandas — удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных. С этой библиотекой мы сейчас и познакомимся.
#
# Основной объект в pandas это DataFrame, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и stackoverflow.

# %%
# %pylab inline  
# import almost all we need
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Данные можно скачать [отсюда](https://www.dropbox.com/s/5qq94wzmbw4e54r/data.csv?dl=0).

# %% [markdown]
# #### 1. [0.5 баллов] Откройте файл с таблицей (не забудьте про её формат). Выведите последние 10 строк.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы?

# %%
#i moved data.csv to the task folder (for convenience) 

data = pd.read_csv('data.csv')
data.tail(10)
# Out:
#       order_id  quantity            item_name  \
# 4612      1831         1        Carnitas Bowl
# 4613      1831         1                Chips
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25
# 4613                                                NaN     $2.15
# 4614                                                NaN     $1.50
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %% [markdown]
# *Данные представляют из себя таблицу, состоящую из 4622 строк (объектов) и 5 столбцов (признаков). Вероятно, это данные о продажах мексиканской забегаловки, в первом столбце указывается id заказа, в третьем столбце - название блюда из заказа, а во втором - количество этого блюда, в четвёртом и пятом указываются рецептура и стоимость соответственно.*

# %% [markdown]
# #### 2. [0.25 баллов] Ответьте на вопросы:
# 1. Сколько заказов попало в выборку?
# 2. Сколько уникальных категорий товара было куплено? (item_name)

# %%
data['order_id'] = data['order_id'].astype('object')
data.describe(include = ['object'])
# Out:
#         order_id     item_name choice_description item_price
# count       4622          4622               3376       4622
# unique      1834            50               1043         78
# top          926  Chicken Bowl        [Diet Coke]     $8.75
# freq          23           726                134        730

# %% [markdown]
# *В выборку попало 1834 заказа, было куплено 50 уникальных категорий товара.*

# %% [markdown]
# #### 3. [0.25 баллов] Есть ли в данных пропуски? В каких колонках?

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null object
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null object
# dtypes: int64(1), object(4)
# memory usage: 180.6+ KB

# %% [markdown]
# *Пропуски есть в одной колонке,* **choice_description**.

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок и нулём для числовых.

# %%
data = data.fillna('')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    4622 non-null object
# item_price            4622 non-null object
# dtypes: int64(2), object(3)
# memory usage: 180.6+ KB

# %% [markdown]
# #### 4. [0.5 баллов] Посмотрите внимательнее на колонку с ценой товара. Какого она типа? Создайте новую колонку так, чтобы в ней цена была числом.
#
# Для этого попробуйте применить функцию-преобразование к каждой строке вашей таблицы (для этого есть соответствующая функция).

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    4622 non-null object
# item_price            4622 non-null object
# dtypes: int64(2), object(3)
# memory usage: 180.6+ KB

# %% [markdown]
# *Данные в колонке с ценой товара типа object.*

# %%
data['new_item_price'] = data['item_price'].map(lambda x: str(x).lstrip('$')).astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    4622 non-null object
# item_price            4622 non-null object
# new_item_price        4622 non-null float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 216.7+ KB

# %% [markdown]
# Какая средняя/минимальная/максимальная цена у товара?

# %%
data['new_item_price_quantity'] = data['new_item_price'] / data['quantity'] 
data['new_item_price_quantity'].describe()
# Out:
# count    4622.000000
# mean        7.084424
# std         3.665487
# min         1.090000
# 25%         2.950000
# 50%         8.750000
# 75%         9.250000
# max        11.890000
# Name: new_item_price_quantity, dtype: float64

# %% [markdown]
# *Средняя цена = 7.084424 долл.\
# Минимальная цена = 1.09 долл.\
# Максимальная цена = 11.89 долл.*

# %% [markdown]
# Удалите старую колонку с ценой.

# %%
data = data.drop(['item_price'], axis = 1)

# %% [markdown]
# #### 5. [0.25 баллов] Какие 5 товаров были самыми дешёвыми и самыми дорогими? (по item_name)
#
# Для этого будет удобно избавиться от дубликатов и отсортировать товары. Не забудьте про количество товара.

# %%
data = data.sort_values(by = 'new_item_price_quantity', ascending = False)
data.drop_duplicates(['item_name'], keep = 'first')
# Out:
#       order_id  quantity                              item_name  \
# 2442       970         1                    Barbacoa Salad Bowl
# 2957      1176         1                       Steak Salad Bowl
# 4239      1692         1                    Carnitas Salad Bowl
# 3211      1284         1                    Barbacoa Soft Tacos
# 2231       899         1                     Steak Crispy Tacos
# 1901       767         1                             Steak Bowl
# 1202       491         1                       Barbacoa Burrito
# 1199       491         1                          Steak Burrito
# 1908       770         1                          Carnitas Bowl
# 2073       836         1                          Barbacoa Bowl
# 4386      1750         1                       Carnitas Burrito
# 2898      1153         1                    Carnitas Soft Tacos
# 1353       552         1                       Steak Soft Tacos
# 485        205         1                  Barbacoa Crispy Tacos
# 1008       413         1                  Carnitas Crispy Tacos
# 986        405         1                        Chicken Burrito
# 1982       801         1                         Veggie Burrito
# 2530      1006         1                            Veggie Bowl
# 3743      1497         1                           Chicken Bowl
# 768        317         1                   Chicken Crispy Tacos
# 3797      1521         1                     Chicken Salad Bowl
# 1699       688         1                      Veggie Soft Tacos
# 1938       784         1                     Chicken Soft Tacos
# 1884       760         1                      Veggie Salad Bowl
# 250        109         1                          Chicken Salad
# 664        276         1                            Steak Salad
# 3750      1500         1                         Carnitas Salad
# 4084      1635         1                           Veggie Salad
# 1653       668         1                    Veggie Crispy Tacos
# 760        313         1                                Burrito
# 673        279         1                                   Bowl
# 520        217         1                           Crispy Tacos
# 1414       575         1                                  Salad
# 2232       899         1                      6 Pack Soft Drink
# 212         93         1                    Chips and Guacamole
# 2088       842         1                                   Izze
# 3368      1351         1                       Nantucket Nectar
# 674        279         1      Chips and Mild Fresh Tomato Salsa
# 4328      1727         1  Chips and Tomatillo Green Chili Salsa
# 1382       561         1    Chips and Tomatillo Red Chili Salsa
# 2571      1018         1           Chips and Fresh Tomato Salsa
# 1597       647         1     Chips and Roasted Chili Corn Salsa
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 648        268         1     Chips and Roasted Chili-Corn Salsa
# 349        150         1    Chips and Tomatillo-Red Chili Salsa
# 2258       909         2                                  Chips
# 2944      1170         3                          Side of Chips
# 4189      1673         1                          Bottled Water
# 1790       724         1                      Canned Soft Drink
# 51          23         2                            Canned Soda
#
#                                      choice_description  new_item_price  \
# 2442  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...           11.89
# 2957  [Fresh Tomato Salsa, [Black Beans, Cheese, Gua...           11.89
# 4239  [Tomatillo Green Chili Salsa, [Black Beans, Ch...           11.89
# 3211  [Roasted Chili Corn Salsa, [Rice, Black Beans,...           11.75
# 2231                    [Fresh Tomato Salsa, Guacamole]           11.75
# 1901  [Roasted Chili Corn Salsa, [Rice, Black Beans,...           11.75
# 1202  [Fresh Tomato Salsa, [Rice, Pinto Beans, Guaca...           11.75
# 1199  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...           11.75
# 1908  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...           11.75
# 2073  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...           11.75
# 4386  [Roasted Chili Corn Salsa, [Rice, Pinto Beans,...           11.75
# 2898  [Tomatillo Red Chili Salsa, [Rice, Black Beans...           11.75
# 1353  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...           11.75
# 485                     [Fresh Tomato Salsa, Guacamole]           11.75
# 1008  [Tomatillo Green Chili Salsa, [Rice, Black Bea...           11.75
# 986   [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...           11.25
# 1982  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...           11.25
# 2530  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...           11.25
# 3743  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...           11.25
# 768   [Roasted Chili Corn Salsa, [Rice, Cheese, Guac...           11.25
# 3797  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...           11.25
# 1699  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...           11.25
# 1938  [Tomatillo Green Chili Salsa, [Sour Cream, Gua...           11.25
# 1884  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...           11.25
# 250   [Roasted Chili Corn Salsa (Medium), [Black Bea...           10.98
# 664   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...            8.99
# 3750  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...            8.99
# 4084  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...            8.49
# 1653  [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...            8.49
# 760   [White Rice, Adobo-Marinated and Grilled Steak...            7.40
# 673   [Adobo-Marinated and Grilled Steak, [Sour Crea...            7.40
# 520                 [Adobo-Marinated and Grilled Steak]            7.40
# 1414  [Brown Rice, Adobo-Marinated and Grilled Chick...            7.40
# 2232                                             [Coke]            6.49
# 212                                                                4.45
# 2088                                       [Clementine]            3.39
# 3368                          [Pineapple Orange Banana]            3.39
# 674                                                                3.00
# 4328                                                               2.95
# 1382                                                               2.95
# 2571                                                               2.95
# 1597                                                               2.95
# 3                                                                  2.39
# 648                                                                2.39
# 349                                                                2.39
# 2258                                                               4.30
# 2944                                                               5.07
# 4189                                                               1.50
# 1790                                             [Coke]            1.25
# 51                                       [Mountain Dew]            2.18
#
#       new_item_price_quantity
# 2442                    11.89
# 2957                    11.89
# 4239                    11.89
# 3211                    11.75
# 2231                    11.75
# 1901                    11.75
# 1202                    11.75
# 1199                    11.75
# 1908                    11.75
# 2073                    11.75
# 4386                    11.75
# 2898                    11.75
# 1353                    11.75
# 485                     11.75
# 1008                    11.75
# 986                     11.25
# 1982                    11.25
# 2530                    11.25
# 3743                    11.25
# 768                     11.25
# 3797                    11.25
# 1699                    11.25
# 1938                    11.25
# 1884                    11.25
# 250                     10.98
# 664                      8.99
# 3750                     8.99
# 4084                     8.49
# 1653                     8.49
# 760                      7.40
# 673                      7.40
# 520                      7.40
# 1414                     7.40
# 2232                     6.49
# 212                      4.45
# 2088                     3.39
# 3368                     3.39
# 674                      3.00
# 4328                     2.95
# 1382                     2.95
# 2571                     2.95
# 1597                     2.95
# 3                        2.39
# 648                      2.39
# 349                      2.39
# 2258                     2.15
# 2944                     1.69
# 4189                     1.50
# 1790                     1.25
# 51                       1.09

# %% [markdown]
# *5 самых дорогих товаров: Barbacoa Salad Bowl, Steak Salad Bowl, Carnitas Salad Bowl,* **а также любые два товара по цене 11.75 долл.,** *например, Carnitas Bowl, Barbacoa Soft Tacos.*

# %%
data.drop_duplicates(['item_name'], keep = 'last')
# Out:
#       order_id  quantity                              item_name  \
# 1865       756         1                    Carnitas Salad Bowl
# 4572      1818         1                       Steak Salad Bowl
# 1418       576         1                    Barbacoa Salad Bowl
# 268        117         1                    Barbacoa Soft Tacos
# 3750      1500         1                         Carnitas Salad
# 3308      1326         1                    Carnitas Soft Tacos
# 1019       419         1                  Barbacoa Crispy Tacos
# 3338      1338         1                          Carnitas Bowl
# 1838       744         1                  Carnitas Crispy Tacos
# 175         78         1                       Steak Soft Tacos
# 960        394         1                      Veggie Salad Bowl
# 693        286         1                     Chicken Salad Bowl
# 3502      1406         1                            Steak Salad
# 729        301         1                     Steak Crispy Tacos
# 3902      1564         1                       Barbacoa Burrito
# 3252      1302         1                       Carnitas Burrito
# 3195      1278         1                          Barbacoa Bowl
# 3196      1278         1                             Steak Bowl
# 1272       517         1                          Steak Burrito
# 1395       567         1                      Veggie Soft Tacos
# 2549      1010         1                   Chicken Crispy Tacos
# 1694       686         1                           Veggie Salad
# 1897       765         1                     Chicken Soft Tacos
# 164         74         1                            Veggie Bowl
# 1652       668         1                         Veggie Burrito
# 1653       668         1                    Veggie Crispy Tacos
# 3989      1598         1                          Chicken Salad
# 4067      1628         1                        Chicken Burrito
# 3101      1237         1                           Chicken Bowl
# 519        217         1                                Burrito
# 521        217         1                           Crispy Tacos
# 1415       575         1                                  Salad
# 445        193         3                                   Bowl
# 3789      1517         1                      6 Pack Soft Drink
# 3825      1533         1                    Chips and Guacamole
# 1706       690         1                       Nantucket Nectar
# 47          21         1                                   Izze
# 674        279         1      Chips and Mild Fresh Tomato Salsa
# 708        291         1     Chips and Roasted Chili Corn Salsa
# 3136      1250         1    Chips and Tomatillo Red Chili Salsa
# 2296       922         1  Chips and Tomatillo Green Chili Salsa
# 3650      1459         1    Chips and Tomatillo-Red Chili Salsa
# 2140       861         1     Chips and Roasted Chili-Corn Salsa
# 2161       872         1  Chips and Tomatillo-Green Chili Salsa
# 3826      1533         1           Chips and Fresh Tomato Salsa
# 4509      1793         1                                  Chips
# 3157      1260         1                          Side of Chips
# 380        165         1                      Canned Soft Drink
# 2981      1186         1                          Bottled Water
# 646        267         1                            Canned Soda
#
#                                      choice_description  new_item_price  \
# 1865   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]            9.39
# 4572  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...            9.39
# 1418                         [Roasted Chili Corn Salsa]            9.39
# 268   [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans...            8.99
# 3750  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...            8.99
# 3308  [Roasted Chili Corn Salsa (Medium), [Black Bea...            8.99
# 1019  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...            8.99
# 3338  [[Roasted Chili Corn Salsa (Medium), Tomatillo...            8.99
# 1838  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...            8.99
# 175        [Roasted Chili Corn Salsa (Medium), Lettuce]            8.99
# 960   [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...            8.75
# 693   [Fresh Tomato Salsa, [Sour Cream, Cheese, Lett...            8.75
# 3502                        [[Lettuce, Fajita Veggies]]            8.69
# 729            [Fresh Tomato (Mild), [Lettuce, Cheese]]            8.69
# 3902  [Fresh Tomato (Mild), [Black Beans, Rice, Sour...            8.69
# 3252             [Fresh Tomato (Mild), [Lettuce, Rice]]            8.69
# 3195  [Fresh Tomato (Mild), [Lettuce, Black Beans, R...            8.69
# 3196  [Fresh Tomato (Mild), [Lettuce, Black Beans, R...            8.69
# 1272  [Tomatillo Red Chili (Hot), [Lettuce, Rice, So...            8.69
# 1395  [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...            8.49
# 2549  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Let...            8.49
# 1694  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...            8.49
# 1897  [Fresh Tomato Salsa (Mild), [Cheese, Sour Crea...            8.49
# 164   [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...            8.49
# 1652  [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...            8.49
# 1653  [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...            8.49
# 3989  [Roasted Chili Corn (Medium), [Lettuce, Black ...            8.19
# 4067                  [[Lettuce, Rice, Fajita Veggies]]            8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...            8.19
# 519   [Braised Barbacoa, Pinto Beans, [Sour Cream, S...            7.40
# 521               [Adobo-Marinated and Grilled Chicken]            7.40
# 1415  [White Rice, Adobo-Marinated and Grilled Chick...            7.40
# 445   [Braised Carnitas, Pinto Beans, [Sour Cream, C...           22.20
# 3789                                        [Diet Coke]            6.49
# 3825                                                               3.89
# 1706                                            [Apple]            3.39
# 47                                         [Blackberry]            3.39
# 674                                                                3.00
# 708                                                                2.95
# 3136                                                               2.95
# 2296                                                               2.95
# 3650                                                               2.39
# 2140                                                               2.39
# 2161                                                               2.39
# 3826                                                               2.29
# 4509                                                               1.99
# 3157                                                               1.69
# 380                                              [Coke]            1.25
# 2981                                                               1.09
# 646                                            [Sprite]            1.09
#
#       new_item_price_quantity
# 1865                     9.39
# 4572                     9.39
# 1418                     9.39
# 268                      8.99
# 3750                     8.99
# 3308                     8.99
# 1019                     8.99
# 3338                     8.99
# 1838                     8.99
# 175                      8.99
# 960                      8.75
# 693                      8.75
# 3502                     8.69
# 729                      8.69
# 3902                     8.69
# 3252                     8.69
# 3195                     8.69
# 3196                     8.69
# 1272                     8.69
# 1395                     8.49
# 2549                     8.49
# 1694                     8.49
# 1897                     8.49
# 164                      8.49
# 1652                     8.49
# 1653                     8.49
# 3989                     8.19
# 4067                     8.19
# 3101                     8.19
# 519                      7.40
# 521                      7.40
# 1415                     7.40
# 445                      7.40
# 3789                     6.49
# 3825                     3.89
# 1706                     3.39
# 47                       3.39
# 674                      3.00
# 708                      2.95
# 3136                     2.95
# 2296                     2.95
# 3650                     2.39
# 2140                     2.39
# 2161                     2.39
# 3826                     2.29
# 4509                     1.99
# 3157                     1.69
# 380                      1.25
# 2981                     1.09
# 646                      1.09

# %% [markdown]
# *5 самых дешёвых товаров: Chips, Side of Chips, Canned Soft Drink, Bottled Water, Canned Soda.*

# %% [markdown]
# #### 6. [0.5 баллов] Какой средний чек у заказа? Сколько в среднем товаров покупают?
#
# Если необходимо провести вычисления в терминах заказов, то будет удобно сгруппировать строки по заказам и посчитать необходимые статистики.

# %%
data.new_item_price.sum() / data.order_id.nunique()
# Out:
# 18.811428571428568

# %%
data.quantity.sum() / data.order_id.nunique()
# Out:
# 2.711014176663032

# %% [markdown]
# *Средний чек = 18.811428571428568\
# Среднее количество товаров = 2.711014176663032*

# %% [markdown]
# #### 7. [0.25 баллов] Сколько заказов содержали ровно 1 товар?

# %%
data_t = data.groupby('order_id').sum()
data_t[data_t['quantity'] == 1].shape[0]
# Out:
# 56

# %% [markdown]
# *56 заказов содержали ровно 1 товар*

# %% [markdown]
# #### 8. [0.75 баллов] Создайте новый DateFrame из матрицы, созданной ниже. Назовите колонки index, column1, column2 и сделайте первую колонку индексом.

# %%
df = np.random.rand(10, 3)
df = pd.DataFrame(df, columns = ['index', 'column1', 'column2']).set_index('index')

# %% [markdown]
# Сохраните DataFrame на диск в формате csv без индексов и названий столбцов.

# %%
df.to_csv('new_df', index = False, header = False)

# %% [markdown]
# ## 2. Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. В этом разделе мы этим и займёмся.
#
# У matplotlib, конечно, же есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторое величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить каждый из них. Не менее важно усвоить базовые принципы визуализаций:
# - на графиках должны быть подписаны оси;
# - у визуализации должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах).
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать.

# %%
# нужно для отображения графиков внутри ноутбука
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# На самом деле мы уже импортировали matplotlib внутри %pylab inline в начале задания.
#
# Работать мы будем с той же выборкой покупкок. Добавим новую колонку с датой покупки.

# %%
import datetime

start = datetime.datetime(2018, 1, 1)
end = datetime.datetime(2018, 1, 31)
delta_seconds = int((end - start).total_seconds())

dates = pd.DataFrame(index=data.order_id.unique())
dates['date'] = [
    (start + datetime.timedelta(seconds=random.randint(0, delta_seconds))).strftime('%Y-%m-%d')
    for _ in range(data.order_id.nunique())]

# если DataFrame с покупками из прошлого заказа называется не df, замените на ваше название ниже
data['date'] = data.order_id.map(dates['date'])

# %% [markdown]
# #### 1. [1 балл] Постройте гистограмму распределения сумм покупок и гистограмму средних цен отдельных видов продуктов item_name.
#
# Изображайте на двух соседних графиках. Для этого может быть полезен subplot.

# %%
figures, axis = plt.subplots(1, 2, figsize = (17,5))

# первая гистограмма
axis[0].hist(data.groupby('order_id').sum().new_item_price, bins = 90)
axis[0].set_title('Распределение сумм покупок')
axis[0].set_xlabel('Сумма покупки, долл.')
axis[0].set_ylabel('Количество покупок')
axis[0].grid()


# вторая гистограмма
data_item = data.sort_values(by = 'item_name')
# создадим новый столбец, полученный склеиванием столбцов названия товара и его цены
data_item['merged'] = data_item['item_name'] + data_item['new_item_price_quantity'].astype(str)
# удалим дубликаты в новом столбце, так мы оставим по одному образцу каждой цены определённого товара
data_item = data_item.drop_duplicates(['merged'], keep = 'first')
axis[1].hist(data_item.groupby('item_name').mean().new_item_price_quantity, bins = 30)
axis[1].set_title('Средние цены отдельных видов продуктов')
axis[1].set_xlabel('Цена вида продукта, долл.')
axis[1].set_ylabel('Количество видов')
axis[1].grid()

# %% [markdown]
# #### 2. [1 балл] Постройте график зависимости суммы покупок от дней.

# %%
data2 = data.groupby('date').sum().reset_index()
plt.plot(data2['date'], data2['new_item_price'], marker = 'd')
plt.title('Зависимость суммы покупок от дней')
plt.xlabel('День')
plt.ylabel('Сумма покупок, долл.')
plt.grid()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### 3. [1 балл] Постройте средних сумм покупок по дням недели (bar plot).

# %%
data['weekday'] = data['date'].map(lambda x: str(x)[-2:]).astype(int)
#data
set1 = ['1','8','15','22','29']
set2 = ['2','9','16','23','30']
set3 = ['3','10','17','24','31']
set4 = ['4','11','18','25']
set5 = ['5','12','19','26']
set6 = ['6','13','20','27']
set7 = ['7','14','21','28']

data['weekday'] = np.where((data['weekday'] == 1) | (data['weekday'] == 8)\
                           | (data['weekday'] == 15) | (data['weekday'] == 22)\
                           | (data['weekday'] == 29), 'Monday', data['weekday'])
data['weekday'] = np.where((data['weekday'] == 2) | (data['weekday'] == 9)\
                           | (data['weekday'] == 16) | (data['weekday'] == 23)\
                           | (data['weekday'] == 30), 'Tuesday', data['weekday'])
data['weekday'] = np.where((data['weekday'] == 3) | (data['weekday'] == 10)\
                           | (data['weekday'] == 17) | (data['weekday'] == 24)\
                           | (data['weekday'] == 31), 'Wednesday', data['weekday'])
data['weekday'] = np.where((data['weekday'] == 4) | (data['weekday'] == 11)\
                           | (data['weekday'] == 18) | (data['weekday'] == 25),\
                            'Thursday', data['weekday'])
data['weekday'] = np.where((data['weekday'] == 5) | (data['weekday'] == 12)\
                           | (data['weekday'] == 19) | (data['weekday'] == 26),\
                            'Friday', data['weekday'])
data['weekday'] = np.where((data['weekday'] == 6) | (data['weekday'] == 13)\
                           | (data['weekday'] == 20) | (data['weekday'] == 27),\
                            'Saturday', data['weekday'])
data['weekday'] = np.where((data['weekday'] == 7) | (data['weekday'] == 14)\
                           | (data['weekday'] == 21) | (data['weekday'] == 28),\
                            'Sunday', data['weekday'])
data
# Out:
#       order_id  quantity            item_name  \
# 2442       970         1  Barbacoa Salad Bowl
# 2957      1176         1     Steak Salad Bowl
# 613        253         2     Steak Salad Bowl
# 2401       953         1     Steak Salad Bowl
# 281        123         2     Steak Salad Bowl
# 2804      1114         1     Steak Salad Bowl
# 4239      1692         1  Carnitas Salad Bowl
# 2740      1088         1     Steak Salad Bowl
# 3120      1244         1     Steak Salad Bowl
# 4313      1720         1     Steak Salad Bowl
# 3546      1426         1  Barbacoa Salad Bowl
# 1816       734         1     Steak Salad Bowl
# 1311       534         1     Steak Salad Bowl
# 2610      1035         1  Carnitas Salad Bowl
# 1159       478         1     Steak Salad Bowl
# 1590       644         1     Steak Salad Bowl
# 1571       637         1     Steak Salad Bowl
# 3493      1403         1     Steak Salad Bowl
# 1326       541         1  Barbacoa Salad Bowl
# 3350      1343         1     Steak Salad Bowl
# 606        250         1     Steak Salad Bowl
# 749        309         1     Steak Salad Bowl
# 1229       501         1  Barbacoa Salad Bowl
# 3749      1499         1  Carnitas Salad Bowl
# 1132       468         1  Carnitas Salad Bowl
# 2439       969         1     Steak Salad Bowl
# 1505       612         1     Steak Salad Bowl
# 3208      1283         1  Barbacoa Salad Bowl
# 3211      1284         1  Barbacoa Soft Tacos
# 2231       899         1   Steak Crispy Tacos
# ...        ...       ...                  ...
# 246        108         1          Canned Soda
# 3020      1201         1          Canned Soda
# 2906      1156         2          Canned Soda
# 248        108         1          Canned Soda
# 3021      1201         1        Bottled Water
# 251        109         1          Canned Soda
# 87          38         1        Bottled Water
# 3866      1550         2          Canned Soda
# 3042      1210         1        Bottled Water
# 1091       450         2          Canned Soda
# 2998      1192         2        Bottled Water
# 370        160         1          Canned Soda
# 1396       567         1          Canned Soda
# 4069      1629         1        Bottled Water
# 126         55         1          Canned Soda
# 2754      1093         1        Bottled Water
# 3364      1349         2          Canned Soda
# 228        100         1          Canned Soda
# 3434      1379         1          Canned Soda
# 2922      1162         1        Bottled Water
# 3361      1348         1        Bottled Water
# 1457       591         1          Canned Soda
# 117         51         1          Canned Soda
# 1431       579         1          Canned Soda
# 2961      1177         1          Canned Soda
# 378        164         1          Canned Soda
# 1805       730         1          Canned Soda
# 2520      1001         1          Canned Soda
# 2981      1186         1        Bottled Water
# 646        267         1          Canned Soda
#
#                                      choice_description  new_item_price  \
# 2442  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...           11.89
# 2957  [Fresh Tomato Salsa, [Black Beans, Cheese, Gua...           11.89
# 613   [Tomatillo Red Chili Salsa, [Fajita Vegetables...           23.78
# 2401  [Fresh Tomato Salsa, [Fajita Vegetables, Guaca...           11.89
# 281   [Tomatillo Red Chili Salsa, [Black Beans, Chee...           23.78
# 2804  [Tomatillo Red Chili Salsa, [Rice, Black Beans...           11.89
# 4239  [Tomatillo Green Chili Salsa, [Black Beans, Ch...           11.89
# 2740  [Fresh Tomato Salsa, [Fajita Vegetables, Black...           11.89
# 3120  [Roasted Chili Corn Salsa, [Fajita Vegetables,...           11.89
# 4313  [Roasted Chili Corn Salsa, [Fajita Vegetables,...           11.89
# 3546                    [Fresh Tomato Salsa, Guacamole]           11.89
# 1816  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...           11.89
# 1311  [Roasted Chili Corn Salsa, [Fajita Vegetables,...           11.89
# 2610  [Roasted Chili Corn Salsa, [Fajita Vegetables,...           11.89
# 1159  [Fresh Tomato Salsa, [Rice, Fajita Vegetables,...           11.89
# 1590  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...           11.89
# 1571  [Fresh Tomato Salsa, [Fajita Vegetables, Sour ...           11.89
# 3493  [Roasted Chili Corn Salsa, [Fajita Vegetables,...           11.89
# 1326  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...           11.89
# 3350  [Fresh Tomato Salsa, [Cheese, Guacamole, Lettu...           11.89
# 606   [Fresh Tomato Salsa, [Pinto Beans, Cheese, Gua...           11.89
# 749   [Roasted Chili Corn Salsa, [Rice, Cheese, Lett...           11.89
# 1229  [Fresh Tomato Salsa, [Rice, Fajita Vegetables,...           11.89
# 3749  [Roasted Chili Corn Salsa, [Fajita Vegetables,...           11.89
# 1132  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...           11.89
# 2439  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...           11.89
# 1505  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...           11.89
# 3208  [Tomatillo Red Chili Salsa, [Black Beans, Chee...           11.89
# 3211  [Roasted Chili Corn Salsa, [Rice, Black Beans,...           11.75
# 2231                    [Fresh Tomato Salsa, Guacamole]           11.75
# ...                                                 ...             ...
# 246                                      [Mountain Dew]            1.09
# 3020                                  [Diet Dr. Pepper]            1.09
# 2906                                           [Sprite]            2.18
# 248                                      [Mountain Dew]            1.09
# 3021                                                               1.09
# 251                                   [Diet Dr. Pepper]            1.09
# 87                                                                 1.09
# 3866                                     [Mountain Dew]            2.18
# 3042                                                               1.09
# 1091                                       [Dr. Pepper]            2.18
# 2998                                                               2.18
# 370                                         [Diet Coke]            1.09
# 1396                                        [Coca Cola]            1.09
# 4069                                                               1.09
# 126                                         [Coca Cola]            1.09
# 2754                                                               1.09
# 3364                                        [Coca Cola]            2.18
# 228                                      [Mountain Dew]            1.09
# 3434                                           [Sprite]            1.09
# 2922                                                               1.09
# 3361                                                               1.09
# 1457                                           [Sprite]            1.09
# 117                                   [Diet Dr. Pepper]            1.09
# 1431                                           [Sprite]            1.09
# 2961                                           [Sprite]            1.09
# 378                                      [Mountain Dew]            1.09
# 1805                                           [Sprite]            1.09
# 2520                                        [Coca Cola]            1.09
# 2981                                                               1.09
# 646                                            [Sprite]            1.09
#
#       new_item_price_quantity        date  weekday
# 2442                    11.89  2018-01-11       11
# 2957                    11.89  2018-01-28       28
# 613                     11.89  2018-01-08        8
# 2401                    11.89  2018-01-23  Tuesday
# 281                     11.89  2018-01-09  Tuesday
# 2804                    11.89  2018-01-28       28
# 4239                    11.89  2018-01-02  Tuesday
# 2740                    11.89  2018-01-19       19
# 3120                    11.89  2018-01-21       21
# 4313                    11.89  2018-01-20       20
# 3546                    11.89  2018-01-26       26
# 1816                    11.89  2018-01-14       14
# 1311                    11.89  2018-01-09  Tuesday
# 2610                    11.89  2018-01-17       17
# 1159                    11.89  2018-01-25       25
# 1590                    11.89  2018-01-14       14
# 1571                    11.89  2018-01-05        5
# 3493                    11.89  2018-01-05        5
# 1326                    11.89  2018-01-02  Tuesday
# 3350                    11.89  2018-01-23  Tuesday
# 606                     11.89  2018-01-18       18
# 749                     11.89  2018-01-14       14
# 1229                    11.89  2018-01-19       19
# 3749                    11.89  2018-01-09  Tuesday
# 1132                    11.89  2018-01-15       15
# 2439                    11.89  2018-01-27       27
# 1505                    11.89  2018-01-12       12
# 3208                    11.89  2018-01-28       28
# 3211                    11.75  2018-01-18       18
# 2231                    11.75  2018-01-12       12
# ...                       ...         ...      ...
# 246                      1.09  2018-01-30  Tuesday
# 3020                     1.09  2018-01-15       15
# 2906                     1.09  2018-01-25       25
# 248                      1.09  2018-01-30  Tuesday
# 3021                     1.09  2018-01-15       15
# 251                      1.09  2018-01-20       20
# 87                       1.09  2018-01-29       29
# 3866                     1.09  2018-01-21       21
# 3042                     1.09  2018-01-11       11
# 1091                     1.09  2018-01-23  Tuesday
# 2998                     1.09  2018-01-28       28
# 370                      1.09  2018-01-05        5
# 1396                     1.09  2018-01-05        5
# 4069                     1.09  2018-01-03        3
# 126                      1.09  2018-01-09  Tuesday
# 2754                     1.09  2018-01-15       15
# 3364                     1.09  2018-01-29       29
# 228                      1.09  2018-01-25       25
# 3434                     1.09  2018-01-27       27
# 2922                     1.09  2018-01-20       20
# 3361                     1.09  2018-01-17       17
# 1457                     1.09  2018-01-17       17
# 117                      1.09  2018-01-02  Tuesday
# 1431                     1.09  2018-01-10       10
# 2961                     1.09  2018-01-01        1
# 378                      1.09  2018-01-23  Tuesday
# 1805                     1.09  2018-01-03        3
# 2520                     1.09  2018-01-18       18
# 2981                     1.09  2018-01-14       14
# 646                      1.09  2018-01-07        7
#
# [4622 rows x 8 columns]

# %% [markdown]
# #### 4. [1 балл] Постройте график зависимости денег за товар от купленного количества (scatter plot).

# %%
figure, axis = plt.subplots()
plt.scatter(data['quantity'], data['new_item_price_quantity'])
plt.title('Зависимость денег за товар от купленного количества')
plt.xlabel('Купленное количество')
plt.ylabel('Стоимость товара')
plt.grid()
plt.show()

# %% [markdown]
# Сохраните график в формате pdf (так он останется векторизованным).

# %%
figure.savefig('scatter_plot.pdf')

# %% [markdown]
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.
